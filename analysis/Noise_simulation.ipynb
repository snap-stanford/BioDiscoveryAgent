# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/dfs/scratch0/jianv/bio-logs/noisy-data/ground_truth_IFNG.csv')
df2 = pd.read_csv('/dfs/scratch0/jianv/bio-logs/noisy-data/ground_truth_IFNG_0.01.csv')
df3 = pd.read_csv('/dfs/scratch0/jianv/bio-logs/noisy-data/ground_truth_IFNG_0.1.csv')

# %%
plt.hist(df['Score'].values)
# Out:
# (array([3.000e+00, 2.000e+00, 5.000e+00, 7.000e+00, 2.000e+01, 1.380e+02,
#         9.598e+03, 8.535e+03, 1.020e+02, 8.000e+00]),
#  array([-3.91885, -3.35706, -2.79527, -2.23348, -1.67169, -1.1099 ,
#         -0.54811,  0.01368,  0.57547,  1.13726,  1.69905]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df2['Score'].values)
# Out:
# (array([4.0000e+00, 3.0000e+00, 5.0000e+00, 7.0000e+00, 2.0000e+01,
#         3.0900e+02, 1.1611e+04, 6.3600e+03, 9.1000e+01, 8.0000e+00]),
#  array([-3.86599276, -3.30235219, -2.73871162, -2.17507105, -1.61143048,
#         -1.04778992, -0.48414935,  0.07949122,  0.64313179,  1.20677236,
#          1.77041293]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df3['Score'].values)
# Out:
# (array([1.0000e+00, 2.0000e+00, 3.0000e+00, 4.0000e+00, 1.9000e+01,
#         2.9300e+02, 6.2920e+03, 1.0423e+04, 1.3570e+03, 2.4000e+01]),
#  array([-4.82209726, -4.1521008 , -3.48210434, -2.81210788, -2.14211142,
#         -1.47211495, -0.80211849, -0.13212203,  0.53787443,  1.20787089,
#          1.87786735]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['Score'].values, df2['Score'].values)

# %%
plt.scatter(df['Score'].values, df3['Score'].values)
plt.xlabel('Experiment 1')
plt.ylabel('Experiment 2')
# Out:
# Text(0, 0.5, 'Experiment 2')
