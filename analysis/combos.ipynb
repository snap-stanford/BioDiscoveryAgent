# %%
import scanpy as sc

# %%
import pandas as pd
import pickle as pkl

# %%
with open('/dfs/user/yhr/gears2/GI_data.pkl', 'rb') as f:
    loaded = pkl.load(f)

loaded.keys()
loaded['good_phen']

# %%
# Out:
# dict_keys(['good_phen', 'good_emap', 'Z_phen', 'Z_emap', 'side', 'fitness_mapper_gene', 'good_perturbations', 'good_genes'])

# %%
# Out:
#               AHR    ARID1A    ARRDC3      ATL1    BCORL1      BPGM     CBARP  \
# gene
# AHR     -0.413976 -0.545311 -0.409793 -0.569601 -0.361435 -0.365286 -0.414273
# ARID1A  -0.545311 -0.432052 -0.397391 -0.560885 -0.349261 -0.411211 -0.400002
# ARRDC3  -0.409793 -0.397391 -0.242386 -0.465946 -0.184744 -0.252307 -0.251732
# ATL1    -0.569601 -0.560885 -0.465946 -0.396527 -0.409639 -0.465906 -0.547774
# BCORL1  -0.361435 -0.349261 -0.184744 -0.409639 -0.088226 -0.150549 -0.139571
# ...           ...       ...       ...       ...       ...       ...       ...
# ZBTB1   -0.404949 -0.408829 -0.268162 -0.510435 -0.176593 -0.247707 -0.251126
# ZBTB10  -0.550600 -0.569559 -0.473208 -0.610714 -0.370136 -0.453764 -0.560707
# ZBTB25  -0.305266 -0.334983 -0.181463 -0.441508 -0.098441 -0.210280 -0.202110
# ZC3HAV1 -0.099770 -0.135287 -0.018822 -0.235210  0.075213  0.022321  0.056852
# ZNF318  -0.441418 -0.396699 -0.173358 -0.471158 -0.122497 -0.170979 -0.212694
#
# ...
